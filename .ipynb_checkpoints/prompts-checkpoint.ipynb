# %%
error_prompt = "\nLook closely at the semantic model and the example data points again. Generate the complete fixed code again."
print(error_prompt)
# Out:
# Look closely at the semantic model and the example data points again. Generate the complete fixed code again.

# %%
prompt = "Generate one single and complete code that extracts, processes and merges data from files based on the semantic model to display FinalTable. For this, strictly iterate over run_id first, then over experiment_id in two nested loops."
with open("SM.txt", "r", encoding="utf-8") as file:
    sm = file.read()
with open("data_points.txt", "r", encoding="utf-8") as file:
    data_points = file.read()
prompt = "You create Python code based on a semantic model for data integration in a Jupyter Notebook." + "\nSemantic Model:\n" + sm + data_points + prompt
print(prompt)
# Out:
# You create Python code based on a semantic model for data integration in a Jupyter Notebook.
# Semantic Model:
# :FinalTable a :DataSource;
#     :hasColumns :RUN_ID,
#         :Experiment_ID,
#         :Basis,
#         :Matt_Beads,
#         :Matt_Silica,
#         :Wachs,
#         :Verdicker,
#         :Time_To_Mix,
#         :Time_To_Dispense,
#         :thickness,
#         :gloss_60,
#         :gloss_85,
#         :haze,
#         :CIELAB_10deg_L,
#         :CIELAB_10deg_a,
#         :CIELAB_10deg_b,
#         :Viskos1,
#         :Viskos2,
#         :abrasion0,
#         :abrasion1,
#         :abrasion2,
#         :abrasion3 .
# :viskos_means.csv a :DataSource;
#     :hasColumns "Viskos1, Viskos2" ;
#     :hasDelimiter ";" ;
#     :isAlignedByIndex true ;
#     :alignsWith :FinalTable ;
#     :comment "Each row in viskos_means.csv corresponds positionally to one (RUN_ID, Experiment_ID) entry in FinalTable." .
# :abrasion.csv a :DataSource;
# ...

# %% [markdown]
# The table has None values. Look closely at the semantic model and the example data points again. Generate the complete fixed code again.

# %%
ml_prompt = """Use this table to train a machine learning model to predict viscosity (viskos1) and gloss (gloss60) based on chemical ingredients and process settings in a single model.
Do all the necessary preprocessing.
Try numerous configurations of Gaussian Process and show how the best model performs on MSE, MAPE \& MAE in the scaled space. Generate one complete code."""
